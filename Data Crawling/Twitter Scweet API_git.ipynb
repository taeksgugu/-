# %%
from Scweet.scweet import scrape
from Scweet.user import get_user_information, get_users_following, get_users_followers

# scrape top tweets with the words 'covid','covid19' and without replies. the process is slower as the interval is
# smaller (choose an interval that can divide the period of time betwee, start and max date) scrape english top
# tweets geolocated less than 200 km from Alicante (Spain) Lat=38.3452, Long=-0.481006.
data = scrape(words=['GDPR'], since="2020-07-01", until="2020-12-31", from_account=None, interval=1,
              headless=False, display_type="Latest", save_images=False, lang="en",
              resume=False, filter_replies=False, proximity=False, geocode="51.339695,12.373075,1000km")

# https://github.com/Altimis/Scweet
# Out:
# looking for tweets between 2020-07-01 and 2020-07-02 ...
#  path : https://twitter.com/search?q=(GDPR)%20until%3A2020-07-02%20since%3A2020-07-01%20lang%3Aen%20geocode%3A51.339695,12.373075,1000km&src=typed_query&f=live
# Tweet made at: 2020-07-01T08:58:43.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2020-07-02 and 2020-07-03 ...
#  path : https://twitter.com/search?q=(GDPR)%20until%3A2020-07-03%20since%3A2020-07-02%20lang%3Aen%20geocode%3A51.339695,12.373075,1000km&src=typed_query&f=live
# Tweet made at: 2020-07-02T19:31:34.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2020-07-03 and 2020-07-04 ...
#  path : https://twitter.com/search?q=(GDPR)%20until%3A2020-07-04%20since%3A2020-07-03%20lang%3Aen%20geocode%3A51.339695,12.373075,1000km&src=typed_query&f=live
# Tweet made at: 2020-07-03T20:23:39.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2020-07-04 and 2020-07-05 ...
# ...

# %%
data.to_excel("GDPR_final Crawl_200701_201231.xlsx", index=False)
data
# Out:
#             UserScreenName          UserName                 Timestamp  \
# 0           Sascha Knicker        @lordsoern  2020-07-01T08:58:43.000Z
# 1      Ale Garcia-Rojas M.        @AletaPool  2020-07-02T19:31:34.000Z
# 2           Alessandro Lai    @AlessandroLai  2020-07-03T20:23:39.000Z
# 3         Sebastian Baltes         @s_baltes  2020-07-04T10:33:59.000Z
# 4               Ain Tohvri           @tekkie  2020-07-05T14:41:48.000Z
# ..                     ...               ...                       ...
# 195  Jeroen Wiert Pluimers        @jpluimers  2020-12-26T13:46:15.000Z
# 196        Innocenzo Genna        @InnoGenna  2020-12-26T10:01:45.000Z
# 197                 NGRAVE  @ngrave_official  2020-12-26T09:42:28.000Z
# 198          Andreas Hartl      @Rheinwaerts  2020-12-27T13:18:20.000Z
# 199            Paul Jordan       @pjordan_10  2020-12-29T16:31:54.000Z
#
#                                                   Text  \
# 0           Sascha Knicker\n@lordsoern\n·\n2020년 7월 1일
# ...
