# %%
import pandas as pd
df = pd.read_excel("CCTV Crawling_2.xlsx")
df
# Out:
#                              title  \
# 0                个人信息保护法如何捍卫个人信息安全
# 1               个人信息保护法实施应关注十大核心要点
# 2          《个人信息保护法》即将施行 禁止大数据“杀熟”
# 3        《个人信息保护法》开始施行 “大数据杀熟”涉嫌违法
# 4      权威专家解读来了！《个人信息保护法》将这样影响你我生活
# ..                             ...
# 295       公安部破获侵犯公民个人信息案 信息泄露源头被查清
# 296  网上“黑市”个人信息 随意买卖 查身份信息 只需提供手机号
# 297        深圳千名孕产妇信息被泄露 个人信息安全如何保障
# 298        自住房申请人信息疑遭泄露：个人账号看到别人信息
# 299       韩发生最大个人信息泄露案 涉1亿400条用户信息
#
#                                                    url        date  \
# 0    https://news.cctv.com/2021/09/14/ARTIe1P4nF1k1...  2021-09-14
# 1    https://news.cctv.com/2021/11/09/ARTIdlKiSycqR...  2021-11-09
# 2    https://news.cctv.com/2021/09/13/ARTIqQYk4Ckpw...  2021-09-13
# 3    https://news.cctv.com/2021/11/01/ARTIkGhzEFdc7...  2021-11-01
# 4    https://news.cctv.com/2021/08/24/ARTIIzq1doWzU...  2021-08-24
# ..                                                 ...         ...
# ...

# %%
dd = list(df.date.unique())
dd.sort()
dd
# Out:
# ['2012-08-30',
#  '2012-11-05',
#  '2012-12-25',
#  '2013-01-22',
#  '2013-01-25',
#  '2013-02-01',
#  '2013-02-28',
#  '2013-04-11',
#  '2013-04-12',
#  '2013-05-21',
#  '2013-06-21',
#  '2013-07-01',
#  '2013-08-11',
#  '2013-08-12',
#  '2013-10-12',
#  '2013-10-14',
#  '2014-01-08',
#  '2014-02-26',
#  '2014-03-03',
#  '2014-03-11',
#  '2015-01-11',
#  '2015-01-13',
#  '2015-02-02',
#  '2015-03-15',
#  '2015-03-16',
#  '2015-04-23',
#  '2015-04-27',
#  '2015-05-28',
#  '2015-06-02',
#  '2015-07-24',
#  '2015-08-04',
#  '2015-10-21',
#  '2016-03-13',
#  '2016-03-15',
#  '2016-03-19',
#  '2016-03-31',
#  '2016-05-17',
#  '2016-05-27',
#  '2016-07-18',
#  '2016-08-01',
#  '2016-08-14',
#  '2016-08-26',
#  '2016-09-24',
#  '2016-09-25',
#  '2016-09-26',
#  '2016-10-11',
#  '2016-10-12',
#  '2016-10-22',
#  '2016-10-27',
#  '2016-10-31',
#  '2016-11-03',
#  '2016-11-06',
#  '2016-11-10',
#  '2016-11-14',
#  '2016-11-15',
#  '2016-11-16',
#  '2016-12-09',
#  '2016-12-10',
# ...

# %%
df2 = df.loc[df['date']>='2020-10-01']
df2
# Out:
#                                    title  \
# 0                      个人信息保护法如何捍卫个人信息安全
# 1                     个人信息保护法实施应关注十大核心要点
# 2                《个人信息保护法》即将施行 禁止大数据“杀熟”
# 3              《个人信息保护法》开始施行 “大数据杀熟”涉嫌违法
# 4            权威专家解读来了！《个人信息保护法》将这样影响你我生活
# ..                                   ...
# 282            工信部提醒相关单位、企业和个人强化个人信息保护意识
# 285   加强平台治理，清朗网络空间 盘点2021：中国互联网朝着规范方向发展
# 286  从事App个人信息处理活动 应遵循“知情同意”“最小必要”两项重要原则
# 287              多部门规范“双11”，遇这些情况别客气，投诉！
# 289                       警惕“脱单盲盒”这场危险游戏
#
#                                                    url        date  \
# 0    https://news.cctv.com/2021/09/14/ARTIe1P4nF1k1...  2021-09-14
# 1    https://news.cctv.com/2021/11/09/ARTIdlKiSycqR...  2021-11-09
# 2    https://news.cctv.com/2021/09/13/ARTIqQYk4Ckpw...  2021-09-13
# 3    https://news.cctv.com/2021/11/01/ARTIkGhzEFdc7...  2021-11-01
# 4    https://news.cctv.com/2021/08/24/ARTIIzq1doWzU...  2021-08-24
# ...

# %%
df3 = df2.loc[df2['content'].str.contains("个人信息保护法")]

# %%
df3.to_excel("CCTV 가공.xlsx", index=False)
